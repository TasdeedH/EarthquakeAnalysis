# %% [markdown]
# # Clustering Methods

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import math as math

from sklearn.metrics.pairwise import haversine_distances

from sklearn.cluster import OPTICS

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv('df1.csv')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df
# Out:
#              Date             Time  Latitude  Longitude   Depth  Magnitude  \
# 0      1965-01-02  0 days 13:44:18   19.2460   145.6160  131.60   6.000000
# 1      1965-01-04  0 days 11:29:49    1.8630   127.3520   80.00   5.800000
# 2      1965-01-05  0 days 18:05:58  -20.5790  -173.9720   20.00   6.200000
# 3      1965-01-08  0 days 18:49:43  -59.0760   -23.5570   15.00   5.800000
# 4      1965-01-09  0 days 13:32:50   11.9380   126.4270   15.00   5.800000
# ...           ...              ...       ...        ...     ...        ...
# 23224  2016-12-28  0 days 08:22:12   38.3917  -118.8941   12.30   5.600000
# 23225  2016-12-28  0 days 09:13:47   38.3777  -118.8957    8.80   5.500000
# 23226  2016-12-28  0 days 12:38:51   36.9179   140.4262   10.00   5.933333
# 23227  2016-12-29  0 days 22:30:19   -9.0283   118.6639   79.00   6.333333
# 23228  2016-12-30  0 days 20:08:28   37.3973   141.4103   11.94   5.500000
#
# ...

# %% [markdown]
# ## Extraction + Conversion

# %%
# Extracting Undefined Only
undefined = df[df['Continent'] == 'Undefined']

# %%
undefined.reset_index(inplace = True)

# %%
undefined
# Out:
#        index        Date             Time  Latitude  Longitude   Depth  \
# 0          0  1965-01-02  0 days 13:44:18   19.2460   145.6160  131.60
# 1          2  1965-01-05  0 days 18:05:58  -20.5790  -173.9720   20.00
# 2          3  1965-01-08  0 days 18:49:43  -59.0760   -23.5570   15.00
# 3          4  1965-01-09  0 days 13:32:50   11.9380   126.4270   15.00
# 4          7  1965-01-15  0 days 23:17:42  -13.3090   166.2120   35.00
# ...      ...         ...              ...       ...        ...     ...
# 12401  23207  2016-12-18  0 days 06:15:46  -34.9886  -107.8694   10.00
# 12402  23208  2016-12-18  0 days 06:39:42   -6.3046   154.3530   10.00
# 12403  23217  2016-12-21  0 days 16:43:57   21.5036   145.4172   12.05
# 12404  23218  2016-12-24  0 days 01:32:16   -5.2453   153.5754   35.00
# 12405  23228  2016-12-30  0 days 20:08:28   37.3973   141.4103   11.94
#
#        Magnitude  Year  Month    Country  Continent  MagGroup    DepthGroup  \
# ...

# %%
lat_lon = undefined[['Latitude', 'Longitude']]

# %%
lat_lon_radians = np.radians(lat_lon)

# %% [markdown]
# ## Distance Matrix Calculation

# %%
#distances = haversine_distances(lat_lon_radians, lat_lon_radians)

# %%
#distances
# Out:
# array([[0.        , 0.97988772, 2.43305073, ..., 0.03953655, 0.4488029 ,
#         0.32322043],
#        [0.97988772, 0.        , 1.68791397, ..., 1.00937258, 0.61145258,
#         1.24936127],
#        [2.43305073, 1.68791397, 0.        , ..., 2.47148971, 2.01826328,
#         2.72704424],
#        ...,
#        [0.03953655, 1.00937258, 2.47148971, ..., 0.        , 0.48727627,
#         0.28392019],
#        [0.4488029 , 0.61145258, 2.01826328, ..., 0.48727627, 0.        ,
#         0.77011781],
#        [0.32322043, 1.24936127, 2.72704424, ..., 0.28392019, 0.77011781,
#         0.        ]])

# %% [markdown]
# ## Clustering Process

# %%
optics_c = OPTICS(metric = 'precomputed', min_samples = 50, n_jobs = -1)

# %%
optics_c.fit(distances)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-4bf2620a4c15> in <module>
# ----> 1 optics_c.fit(distances)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_optics.py in fit(self, X, y)
#     252
#     253         (self.ordering_, self.core_distances_, self.reachability_,
# --> 254          self.predecessor_) = compute_optics_graph(
#     255              X=X, min_samples=self.min_samples, algorithm=self.algorithm,
#     256              leaf_size=self.leaf_size, metric=self.metric,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %%
y = pd.read_csv('OPTICS_results.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
clustered = pd.concat([undefined,y], axis = 1)

# %%
clustered
# Out:
#        index        Date             Time  Latitude  Longitude   Depth  \
# 0          0  1965-01-02  0 days 13:44:18   19.2460   145.6160  131.60
# 1          2  1965-01-05  0 days 18:05:58  -20.5790  -173.9720   20.00
# 2          3  1965-01-08  0 days 18:49:43  -59.0760   -23.5570   15.00
# 3          4  1965-01-09  0 days 13:32:50   11.9380   126.4270   15.00
# 4          7  1965-01-15  0 days 23:17:42  -13.3090   166.2120   35.00
# ...      ...         ...              ...       ...        ...     ...
# 12401  23207  2016-12-18  0 days 06:15:46  -34.9886  -107.8694   10.00
# 12402  23208  2016-12-18  0 days 06:39:42   -6.3046   154.3530   10.00
# 12403  23217  2016-12-21  0 days 16:43:57   21.5036   145.4172   12.05
# 12404  23218  2016-12-24  0 days 01:32:16   -5.2453   153.5754   35.00
# 12405  23228  2016-12-30  0 days 20:08:28   37.3973   141.4103   11.94
#
#        Magnitude  Year  Month    Country  Continent  MagGroup    DepthGroup  \
# ...

# %%
import folium
from folium import Choropleth
from folium.plugins import HeatMap

# %%
clustered.to_csv(r'C:\Personal\City University\MSc Data Science\Github\VA\clustered_delete.csv')

# %%
y['0'].value_counts(ascending = False)
# Out:
# -1      4867
#  292      31
#  735      31
#  302      26
#  763      25
#         ...
#  249       5
#  822       5
#  53        5
#  838       5
#  65        5
# Name: 0, Length: 856, dtype: int64
